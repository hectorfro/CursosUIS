# %% [markdown]
# # Uso básico del multímetro.
#
# ## 1. Introducción
#
#
# ## 2. Metodología
#
# - Primero se mide el valor de la resistencia sumistrada haciendo uso del multímetro.
#
# - Se realiza el montaje experimental para medir voltajes y corrientes sobre la resistencia de valor conocido.
#
# - Se toman un conjunto de mediciones de voltaje y corriente con el fin de calcular el valor de la resistencia utilizando un método gráfico.
#
# - El método gráfico a utilizar es el método de los mínimos cuadrados, y se usa para  calcula el valor de la resistencia ya que esta viene a ser la pendiente de la recta de la gráfica corriente vs voltaje.
#
# - Se utiliza un Notebook de Python para realizar todos los cálculos involucrados en el proceso de los mínimos cuadrados para calcular la pendiente $m$. y de $b$ de la ecuación de la recta $y=mx+b$
#
# - El resultado obtenido en el método se comparará con el valor de la resistencia medida originalmente.
#
#
# ###  Materiales:
#
# Los materiales utilizados para la realización de este  trabajo fueron los siguientes:
#
# - 1 Fuente de corriente continua
# - 2 Multímetros
# - 1 Resistencia de valor 150 $\Omega$ (según la fábrica)
# - 1 Juego de cables
# - 1 tablero de conexiones
#
#
# ### Montaje experimental
#
# Se monta el circuito mostrado el la figura 1, el cual consiste en una circuito con una resistencia en serie a la fuente de poder, un multímetro para medir el voltaje en la resistencia y un amperímetro para medir la corriente que pasa por la resistencia.
#
#
# <font color='red'>(Aquí va la figura 1 del circuito)</font>
#
#
#
# La sensibilidad de los aparatos de medición son: $\Delta \Omega= \pm 0,1 \Omega$, $\Delta V=\pm 0,001$ (V) y  $\Delta I=\pm 0,001 $ (A)
#
#
#
# ### La toma de datos
#
# - 1) Se mide el valor de la resistencia con el multímetro en la opción para medir ohmios.
#
# $$
# R_{medida}= 149,9 \pm 0.1 \, \Omega
# $$
#
#
# - 2) Con el montaje experimental en funcionamiento se realizaron el conjunto de medidas mostrado  en la tabla 1. Se midieron directamente los voltajes y corrientes y luego para cada valor de voltaje y corriente se calculó el valor de la resistencia $R$.
#
# $$
# \begin{array}{|c|c|c|}
# \hline \text { Medición } & V (V) & I (A)  \\
# \hline 1 & 10.120& 0.067  \\
# \hline 2 & 9.060 & 0.060  \\
# \hline 3 & 8.100 & 0.054  \\
# \hline 4 & 7.120 & 0.046  \\
# \hline 5 & 6.140 & 0.041  \\
# \hline 6 & 5.110 & 0.033  \\
# \hline 7 & 4.050 & 0.027  \\
# \hline 8 & 3.064 & 0.020  \\
# \hline 9 & 2.137 & 0.013  \\
# \hline 10 & 1.090 & 0.005  \\
# \hline 11 & -10.080& -0.067  \\
# \hline 12 & -9.050 & -0.060  \\
# \hline 13 & -8.050 & -0.055  \\
# \hline 14 & -7.120 & -0.048  \\
# \hline 15 & -6.110 & -0.041  \\
# \hline 16 & -5.090 & -0.035  \\
# \hline 17 & -4.120 & -0.027  \\
# \hline 18 & -3.091 & -0.020  \\
# \hline 19 & -2.058 & -0.014  \\
# \hline 20 & -1.106 & -0.007  \\
# \hline
# \end{array}
# $$
#
#
#
# - 3) Se desarrolla el método de mínimos cuadrados para calcular $R$.
#
# Cuando se utiliza el método de mínimos cuadrados es necesario encontrar de la ecuación lineal
#
# $$
# y=mx+b
# $$
#
# los parámetros $m$ y $b$, es decir, la pendiente de la recta $m$ y el punto de corte con el eje $y$, respectivamente.
#
# En este caso el eje $x$ será el eje de las corrientes y el eje $y$ el de los voltajes:
#
# $$
# V= R I + b
# $$
#
# Es decir, la pendiente de la recta es el valor de la resistencia, por lo tanto:
#
# $$
# R =\dfrac{ n\sum\limits_{i=1}^n I_i V_i-\sum\limits_{i=1}^n I_i \sum\limits_{i=1}^n V_i}{n \sum\limits_{i=1}^n I_i^2-\left(\sum\limits_{i=1}^n I_i\right)^2}\,,\qquad
# b = \dfrac{\sum\limits_{i=1}^n I_i^2 \sum\limits_{i=1}^n V_i-\sum\limits_{i=1}^n I_i \sum\limits_{i=1}^n I_i V_i}{n\sum\limits_{i=1}^n I_i^2-\left(\sum\limits_{i=1}^n I_i\right)^2}
# $$
#
# Primero es necesario encontrar la siguiente serie de sumas:
#
# $$
# \sum V_i,\, \sum I_i,\, \sum I_i^2 \, \text{y} \, \sum I_i V_i
# $$.
#
# Estas sumas son:
#
# $$
# \sum V_i=0.1160 \,, \quad \sum I_i= -0.0080  \,, \quad \sum I_i^2= 0.034912 \,, \quad \sum I_i V_i= 5.2520
# $$
#
# Con estos resultados se obtienen los siguientes valores
#
# $$
# R= 150.449 \, \Omega \, \text{y} \,  b= 0.066 V.
# $$
#
# Es necesario calcular los errores absolutos $\Delta R$ y $\Delta b$
#
# $$
# \Delta R  =\left[\frac{n}{n \sum\limits_{i=1}^n\left(x_i\right)^2-\left(\sum\limits_{i=1}^n x_i\right)^2}\right]^{\frac{1}{2}} S_y \,,\qquad
# \Delta b  =\left[\frac{\sum\limits_{i=1}^n\left(x_i\right)^2}{n \sum\limits_{i=1}^n\left(x_i\right)^2-\left(\sum\limits_{i=1}^n x_i\right)^2}\right]^{\frac{1}{2}} S_y
# $$
#
# donde
#
# \begin{equation}
# S_y=\left[\frac{\sum\limits_{i=1}^n \left(y_i-b-m x_i\right)}{n-2}\right]^{\frac{1}{2}} \,.
# \end{equation}
#
#
# Sustituyendo los valores numéricos se obtiene
# $$
# S_y= 0.2640 \,, \qquad \Delta R=1.412 \, \Omega \,, \qquad \Delta b= 0.06 \, V
# $$
#
# Por lo tanto, por el método de mínimos cuadrados se obtiene un valor para la resistencia de
# $$
# R= 150 \pm 1 \, \Omega
# $$
# Lo que representa un error porcentual del 0.6 %.
#
#
# Teóricamente $b$ debería ser cero, pero en este trabajo se obtuvo el valor de $b= 0.07 \pm 0.06$ V.
#
#
# Este resultado se puede comparar con el que se obtiene usando la librería de Numpy <<linalg.lstsq>>. Con esta librería numérica se obtiene el mismo resultado: $(m=150.449,b= 0.066)$
#
# ## 3. El experimento y los resultados
#
#
#
# ## 4. Conclusiones y recomendaciones

# %%
from numpy import *
import matplotlib.pyplot as plt

# %%
# Los datos
Vn= array([10.120, 9.060, 8.100, 7.120, 6.140, 5.110, 4.050, 3.064, 2.137, 1.090, -10.080, -9.050, -8.050, -7.120, -6.110, -5.090, -4.120, -3.091, -2.058, -1.106])
In= array([0.067, 0.060, 0.054, 0.046, 0.041, 0.033, 0.027, 0.020, 0.013, 0.005,-0.067, -0.060, -0.055, -0.048, -0.041, -0.035, -0.027, -0.020, -0.014, -0.007])

# %%
# El número de datos
n=len(Vn)
n
# Out:
# 20

# %%
# Minimos cuadrados
n=len(Vn)
# Las sumatorias necesarias
Sum_I= sum (In)
Sum_V= sum (Vn)
Sum_II= sum (In**2)
Sum_IV=sum (In*Vn)
print(n,',', Sum_I, ',', Sum_V, ',', Sum_II, ',', Sum_IV)
# Out:
# 20 , -0.007999999999999986 , 0.11599999999999944 , 0.034912 , 5.2519350000000005

# %%
# El cálculo de b y m
b=(Sum_II*Sum_V-Sum_IV*Sum_I)/(n*Sum_II-Sum_I**2)
m=(n*Sum_IV-Sum_I*Sum_V)/(n*Sum_II-Sum_I**2)
print('m=',m.round(3), ',', 'b=',b.round(4))
# Out:
# m= 150.449 , b= 0.066

# %%
# se hace la gráfica V vs I

# Datos
x1=In
y1=Vn

# linea recta
x2=In
y2= m*x2+b

fig,ax = plt.subplots()
# gráfica de los datos
yerr = 0.001
xerr = 0.001

ax.errorbar(x1, y1, yerr=yerr, xerr=xerr,fmt='+',color='b')
ax.set_xlabel('I [A]')
ax.set_ylabel('V [V]')

# gráfica de la recta
ax2 = ax.twinx()
ax2.plot(x2, y2, color="red", linewidth=+1, label= f'$V =$ {m:.0f} $I$ + {b:.2f}')
plt.title('Voltaje vs Corriente', fontsize=20)
plt.legend()
plt.grid(axis='both',color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
# Escribimos las sumatorias para calcular Sy
Sum_d= Sum_V -b-m*Sum_I
Sy=sqrt(Sum_d/(n-2))
print(n,',', Sum_d ,',', Sy)
# Out:
# 20 , 1.2536096457053785 , 0.2639033541222344

# %%
# Cálculo de los errores absolutos de m y b
Δm= (n/((n*Sum_II-Sum_I**2)))**(1/2)*Sy
Δb= (Sum_II/((n*Sum_II-Sum_I**2)))**(1/2)*Sy
print('Δm=', Δm, ',', 'Δb=',Δb)
# Out:
# Δm= 1.4124642027755752 , Δb= 0.0590132885430742

# %% [markdown]
# El uso de la librería <<linalg.lstsq>> se puede consultar en la documentación del Numpy:  https://numpy.org/doc/stable/reference/generated/numpy.linalg.lstsq.html#

# %%
A = vstack([In, ones(len(In))]).T

# %%
m, b = linalg.lstsq(A, Vn, rcond=None)[0]
m.round(3), b.round(3)
# Out:
# (150.449, 0.066)
